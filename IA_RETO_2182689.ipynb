# %% [markdown]
# ##RETO DE ANALITICA DE DATOS
# Geydi Dayana Calderon Salazar - 2182689

# %%
#@title **LIBRERIAS**
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

sns.set_theme()
pd.__version__
# Out:
# '1.3.5'

# %%
#@title **DATASET**
df = pd.read_csv("filterICFES.csv")

# %%
#@markdown Correlación general de las pruebas
plt.subplots(figsize=(25,15)) 
plt.title("CORRELACION COLOMBIA")
corr = df.corr()
sns.heatmap(corr, annot=True, fmt=".2f")
plt.show()

# %%
#@markdown Correlación general del Departamento del Meta. 
plt.subplots(figsize=(25,15)) 
plt.title("CORRELACION DEPARTAMENTO META")
corr_depto=df[df.ESTU_DEPTO_RESIDE==26].corr()
sns.heatmap(corr_depto, annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# **CONCLUSIONES DEPARTAMENTO DEL META**
#
# ---
# Como se puede apreciar en el grafico la correlación del departamento del Meta está demasiado ligada a la correlación en Colombia, dado que los valores para cada correlación están cercanos unos de otros, los resultados fueron los siguientes:
# *   Podemos observar una correlación considerada alta en este departamento en los casos donde las familias tienen computador y las que cuentan con internet (0.47) y a nivel nacional esta correlación tiene un valor de (0.54), esto indica que estos valores están relacionados directamente.
# *   En las variables tiene internet y el percentil global se tiene una correlación positiva (0.23), entonces se demuestra que el contar con internet permite mejorar en el percentil y los demás puntajes con respecto al país.
# *   Podemos notar también que el grado de escolaridad de los padres no influye directamente en los resultados de la prueba hecha por el estudiante, ya que se tiene una correlación muy cercana a cero, esto sucede tanto en el departamento de Meta como a nivel nacional.
# *   Se puede observar que el percentil de lectura crítica tiene una correlación positiva respecto al desempeño de las áreas evaluadas.
# *   En Meta el estrato de la vivienda tiene una correlación positiva respecto a la naturaleza del colegio, a tener internet y computador indicando que estas tres variables están relacionadas con el estrato del estudiante.
# *   Y por último podemos concluir que tanto la variable de percentil global y puntaje global tienen una correlación positiva con tener internet, computador y la naturaleza del colegio.
#
#
# ---

# %%
#@markdown Grafique al menos un histograma, un “violinplot” y un gráfico libre con las variables del icfes que le permitan concluir las fortalezas y desventajas de los estudiantes en Colombia

plt.figure(figsize=(16,16))
plt.subplot(3,2,1)
#histograma
plt.hist(df['PUNT_LECTURA_CRITICA'],  color='orchid')
plt.xlabel('Puntaje lectura critica')
plt.title("AREA LECTURA CRITICA")

plt.subplot(3,2,2)
plt.hist(df['PUNT_INGLES'],  color='indigo')
plt.xlabel('Puntaje ingles ')
plt.title("AREA INGLES")

# violinplot
plt.subplot(3,2,3)
sns.violinplot(x="FAMI_TIENEINTERNET", y="PUNT_GLOBAL", color='hotpink', data=df)
plt.title("INTERNET - PUNTAJE GLOBAL")
plt.xlabel('Tiene Internet')
plt.ylabel('Puntaje Global')

plt.subplot(3,2,4)
sns.violinplot(x="COLE_AREA_UBICACION", y="PUNT_GLOBAL", color='darkviolet', data=df)
plt.title("UBICACION COLEGIO -PUNTAJE GLOBAL")
plt.xlabel('Ubicacion Colegio')
plt.ylabel('Puntaje Global')
# Grafico libre
#bloxplot
plt.subplot(3,2,5)
sns.boxplot(x="FAMI_ESTRATOVIVIENDA", y="PUNT_GLOBAL", data=df, palette="rocket")
plt.title("ESTRATO VIVIENDA - PUNTAJE GLOBAL")
plt.xlabel('Estrato vivienda')
plt.ylabel('Puntaje Global')

plt.subplot(3,2,6)
sns.boxplot(x="FAMI_ESTRATOVIVIENDA", y="PUNT_SOCIALES_CIUDADANAS", data=df, palette="flare")
plt.title("ESTRATO VIVIENDA - PUNTAJE C. SOCIALES Y CIUDADANAS")
plt.xlabel('Estrato vivienda')
plt.ylabel('Puntaje C. Sociales y Ciudadanas')

plt.show()

# %% [markdown]
# **CONCLUSIONES ESTUDIANTES DE COLOMBIA**
#
#
# ---
#
#
# *   Conclusiones histogramas: el histograma que tiene representado los datos del puntaje en el área de lectura crítica, se puede evidenciar que la mayoría de estudiantes obtuvieron un puntaje entre 50 y 60. Y en el histograma que representa el área de inglés, se puede evidenciar que la mayoría de estudiantes obtuvieron un puntaje entre 40-50. De este modo podemos concluir, que una de las fortalezas de los estudiantes de Colombia es en el área de lectura crítica en comparación con el área de inglés.
# *   Conclusiones violinplot: en el primer grafico de violinplot relacionamos las variables de Familia tiene internet y el puntaje global, podemos ver que los estudiantes que cuentan con internet tienen un promedio mayor en el puntaje global. Y en el segundo grafico de violinplot relacionamos la ubicación del colegio y el puntaje global podemos observar que los estudiantes que estudian en un área urbana tienen un promedio mayor en el puntaje global comparado con los que estudian en un área rural.
# *   Conclusiones Boxplot: En el grafico primer grafico podemos observar que los estudiantes de estrato 0 tienen un menor promedio respecto a los demás estratos en el puntaje global, por otro parte, los estudiantes que pertenecen a estratos más altos tienen promedios mejores, puntajes muy cercanos a 500. El segundo grafico relacionamos el estrato respecto a la prueba de C. Sociales y Ciudadanas, nuevamente se presenta las diferencias entre el estrato 0 con los demás, donde se puede evidenciar un menor promedio, en el cual su media está en 40, y se muestra que los estudiantes de estrato 4 y 5 tiene mayor promedio. Con esto podemos concluir que pertenecer a estratos bajos si afecta los resultados ICFES, considerando esto como una desventaja con respecto a los estudiantes con estratos de vivienda más altos.
#
#
# ---

# %%
#@markdown Grafique al menos un histograma, un “violinplot” y un gráfico libre con las variables del ICFES en el departamento del Meta que le permitan concluir las fortalezas y desventajas de los estudiantes en el departamento con respecto a colombia. Concluya con los requerimientos al gobernador justificado en los datos analizados
d26=df[df.ESTU_DEPTO_RESIDE==26]
plt.figure(figsize=(16,16))
plt.subplot(3,2,1)
#histograma
plt.hist(d26['PUNT_LECTURA_CRITICA'],  color='orchid')
plt.xlabel('Puntaje Lectura Critica')
plt.title("AREA LECTURA CRITICA")

plt.subplot(3,2,2)
plt.hist(d26['PUNT_INGLES'],  color='indigo')
plt.xlabel('Puntaje Ingles')
plt.title("AREA INGLES")

#violinplot
plt.subplot(3,2,3)
sns.violinplot(x="FAMI_TIENEINTERNET", y="PUNT_GLOBAL", color='hotpink', data=d26)
plt.title("INTERNET - PUNTAJE GLOBAL")
plt.xlabel('Tiene Internet')
plt.ylabel('Puntaje Global')

plt.subplot(3,2,4)
sns.violinplot(x="COLE_AREA_UBICACION", y="PUNT_GLOBAL", color='darkviolet', data=d26)
plt.title("UBICACION COLEGIO -PUNTAJE GLOBAL")
plt.xlabel('Ubicacion Colegio')
plt.ylabel('Puntaje Global')

# Grafico libre
#bloxplot
plt.subplot(3,2,5)
sns.boxplot(x="FAMI_ESTRATOVIVIENDA", y="PUNT_GLOBAL", data=d26, palette="rocket")
plt.title("ESTRATO VIVIENDA - PUNTAJE GLOBAL")
plt.xlabel('Estrato vivienda')
plt.ylabel('Puntaje Global')

plt.subplot(3,2,6)
sns.boxplot(x="FAMI_ESTRATOVIVIENDA", y="PUNT_SOCIALES_CIUDADANAS", data=d26, palette="flare")
plt.title("ESTRATO VIVIENDA - PUNTAJE C. SOCIALES Y CIUDADANAS")
plt.xlabel('Estrato vivienda')
plt.ylabel('Puntaje C. Sociales y Ciudadanas')
plt.show()

# %% [markdown]
# **CONCLUSIONES ESTUDIANTES DEPARTAMENTO META**
#
# ---
#
#
# *   Conclusiones histogramas: los resultados reflejan que la mayoría de estudiantes del departamento del Meta en la prueba de lectura crítica, obtuvieron un puntaje entre 40-60, y para el área de ingles la mayoría de los estudiantes obtuvieron un puntaje entre 40-50. Podemos concluir que los resultados de estas dos pruebas el departamento respecto al País se encuentra en el mismo nivel.
# *   Conclusiones violinplot: en el primer grafico de violinplot relacionamos las variables de Familia tiene internet y el puntaje global, podemos ver que los estudiantes que cuentan con internet tienen una media mayor a 250 al igual que en Colombia, siendo esta mayor que la media de los estudiantes que no tienen computador.  Y en el segundo grafico de violinplot relacionamos la ubicación del colegio y el puntaje global, a diferencia de Colombia, en este grafico se observa que no afecta en gran parte el hecho de vivir en un área rural o urbana, sin embargo, si se evidencia que los estudiantes de zonas urbanas alcanzaron un puntaje mayor, cerca de 500.
# *   Conclusiones Boxplot: En el primer grafico podemos observar que los estudiantes de estrato 0 tienen una media menor respecto a los demás estratos en el puntaje global. En el Meta el promedio más alto fue en los estudiantes de estrato 6, mientras que en Colombia el estrato con mejor media estuvo en el estrato 4. Pero tanto a nivel departamental como nacional el estrato 0 fue el de menor promedio. El segundo grafico relacionamos el estrato respecto a la prueba de C. Sociales y Ciudadanas, nuevamente se presenta las diferencias entre el estrato 0 con los demás, donde se puede evidenciar un menor promedio.  En el Meta se evidencio mayores desventajas entre los estratos bajos y más altos que en los puntajes en Colombia.
#
#
# ---

# %% [markdown]
# **REQUERIMIENTOS AL GOBERNADOR**
#
#
# ---
#
#
# Partiendo de los análisis y conclusiones anteriores, los requerimientos para el departamento del Meta sería la implementación de internet, tanto en zonas rurales y urbanas para obtener una mejora en los puntajes y media, por ende, la posibilidad de acceso a computadores, ya que estas dos variables son positivamente correlacionadas, dado que se demuestra una mejor puntación en estudiantes que cuentan con ello. En cuanto a los estudiantes de estratos más bajos, se requiere un seguimiento en su educación, como dispositivos electrónicos, internet, alimentación y vivienda para obtener mejores resultados con respecto al país y departamento. Por otra parte, se debe reforzar el área de inglés, ya que la puntuación de la media es bastante baja, lo que implica que se debe reforzar, una forma sería llevando a cabo nuevas estrategias de aprendizaje y metodologías más eficientes.
#
#
#
# ---
